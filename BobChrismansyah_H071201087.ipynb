# %% [markdown]
# <a href="https://colab.research.google.com/github/BobChrismansyah/Data-Mining/blob/main/BobChrismansyah_H071201087.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <b>Nama : Bob Chrismansyah Pata'dungan Kabanga
#
# NIM  : H071201087

# %% [markdown]
# * Cari dan unduh data set dari repository Kaggle dan UCI Machine Learning
#
#     Saya menggunakan data <b>Popular Programming Language</b>

# %%
import pandas as pd
data = pd.read_csv("Popular Programming Language.csv")
data
# Out:
#         Language  ... 2019.1
# 0        Fortran  ...    NaN
# 1          COBOL  ...    NaN
# 2          ALGOL  ...    NaN
# 3       Assembly  ...    NaN
# 4          BASIC  ...    NaN
# 5           Lisp  ...    NaN
# 6            APL  ...    NaN
# 7         Pascal  ...    NaN
# 8              C  ...   5.35
# 9            Ada  ...    NaN
# 10           C++  ...   6.62
# 11  Visual Basic  ...    NaN
# 12          Perl  ...    NaN
# 13    JavaScript  ...  23.18
# 14          Java  ...  22.39
# 15        Delphi  ...    NaN
# 16           PHP  ...   7.19
# 17            C#  ...   8.41
# 18        Python  ...  24.27
# 19          Ruby  ...   2.10
# 20        Matlab  ...    NaN
# 21   Objective C  ...   3.47
# 22             R  ...   4.36
# 23         Swift  ...   3.76
# 24        Kotlin  ...   2.64
#
# [25 rows x 59 columns]

# %% [markdown]
# * Dataset diatas menggambarkan tentang seberapa populer suatu bahasa pemrograman dalam waktu tertentu dihitung mulai dari tahun 1965 sampai 2019.
#
# * Data ini bertujuan untuk mengetahui kapan bahasa pemrograman tersebut populer
#
# * Atribut - atributnya yaitu :
#     * Waktu
#     * Bahasa Pemrograman
#     * link gambar
#
# * objectnya bahasa pemrograman

# %%
data.hist(figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f78a2cb1e50>,
# ...
#       dtype=object)

# %% [markdown]
# Cek nama kolom

# %%
data.columns
# Out:
# Index(['Language', 'Image URL', '1965', '1965.1', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2019.1'],
#       dtype='object')

# %% [markdown]
# Akses kolom <b>Language</b>

# %%
data['Language']
# Out:
# 0          Fortran
# 1            COBOL
# 2            ALGOL
# 3         Assembly
# 4            BASIC
# 5             Lisp
# 6              APL
# 7           Pascal
# 8                C
# 9              Ada
# 10             C++
# 11    Visual Basic
# 12            Perl
# 13      JavaScript
# 14            Java
# 15          Delphi
# 16             PHP
# 17              C#
# 18          Python
# 19            Ruby
# 20          Matlab
# 21     Objective C
# 22               R
# 23           Swift
# 24          Kotlin
# Name: Language, dtype: object

# %% [markdown]
# Cek berapa jumlah data yang kosong

# %%
print(data.isnull().values.any())
# Out:
# True

# %% [markdown]
# Menampilkan data yang kosong

# %%
data.isnull().sum()
# Out:
# Language      0
# Image URL     0
# 1965         18
# 1965.1       18
# 1966         25
# 1967         25
# 1968         25
# 1969         18
# 1970         17
# 1971         25
# 1972         25
# 1973         25
# 1974         25
# 1975         16
# 1976         25
# 1977         25
# 1978         25
# 1979         25
# 1980         14
# 1981         25
# 1982         25
# 1983         25
# 1984         25
# 1985         14
# 1986         25
# 1987         25
# 1988         25
# 1989         25
# 1990         13
# 1991         24
# 1992         25
# 1993         25
# 1994         25
# 1995         12
# 1996         11
# 1997         12
# 1998         12
# 1999         24
# 2000         13
# 2001         12
# 2002         23
# 2003         24
# 2004         25
# 2005         14
# 2006         12
# 2007         23
# 2008         25
# 2009         13
# 2010         13
# 2011         24
# 2012         14
# 2013         13
# 2014         12
# 2015         24
# 2016         24
# ...

# %% [markdown]
# Deskripsi informasi statik dari data

# %%
data.describe()
# Out:
#             1965     1965.1  1966  1967  ...  2017       2018       2019     2019.1
# count   7.000000   7.000000   0.0   0.0  ...   0.0  11.000000  12.000000  12.000000
# mean   13.122857  13.122857   NaN   NaN  ...   NaN  10.256364   9.478333   9.478333
# std    20.430100  20.430100   NaN   NaN  ...   NaN   8.195085   8.533520   8.533520
# min     1.000000   1.000000   NaN   NaN  ...   NaN   2.790000   2.100000   2.100000
# 25%     1.740000   1.740000   NaN   NaN  ...   NaN   4.270000   3.687500   3.687500
# 50%     5.380000   5.380000   NaN   NaN  ...   NaN   6.980000   5.985000   5.985000
# 75%    11.910000  11.910000   NaN   NaN  ...   NaN  14.890000  11.905000  11.905000
# max    58.180000  58.180000   NaN   NaN  ...   NaN  23.920000  24.270000  24.270000
#
# [8 rows x 57 columns]
